# %% [markdown]
# <a href="https://colab.research.google.com/github/habibihamka/awesome-github-profile-readme/blob/master/X_PPLG_HABIBI%20HAMKA_Tugas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tugas 1
#  Praktik 1 Membuat Tipe Data Dan Variabel
#
# Nama kelompok: IQ+Ketenangan
# Nama Anggota:
# 1. Habibi Hamka
# 2. Syafiq Hakim
# 3. Rafa Anurwansyah
# 4. Satria Aprilliansyah
# 5. Fiqih Ramadhan

# %%
# %%writefile praktik_variabel.cpp
# #include <iostream>
# #include <string>
# using namespace std;
#
# int main() {
#     // Deklarasi Variabel dan Tipe Data
#     string namaBarang = "iPhone Kupih";
#     int jumlah = 2;
#     float harga = 7500000.50;
#     char kategori = 'A';
#     bool tersedia = true;
#
#     // Menampilkan Output ke Layar
#     cout << "=== DATA INVENTARIS ===" << endl;
#     cout << "iPhone Kupih: " << namaBarang << endl;
#     cout << "Kategori    : " << kategori << endl;
#     cout << "Jumlah      : " << jumlah << endl;
#     cout << "75000000.50 : Rp " << harga << endl;
#     cout << "Tersedia    : " << tersedia << " (1 = Ya, 0 = Tidak)" << endl;
#     cout << "=======================" << endl;
#
#     return 0;
# }
# Out:
# Overwriting praktik_variabel.cpp

# %%
# !g++ praktik_variabel.cpp -o praktik_variabel

# !./praktik_variabel
# Out:
# === DATA INVENTARIS ===
# iPhone Kupih: iPhone Kupih
# Kategori    : A
# Jumlah      : 2
# 75000000.50 : Rp 7.5e+06
# Tersedia    : 1 (1 = Ya, 0 = Tidak)
# ...

# %% [markdown]
# Tugas 1
# praktik 2 : menerima input (cin) dari pengguna
# Nama kelompok:IQ+KETENANGAN
# NAMA ANGGOTA:
# . Habibi Hamka
# 2. Syafiq Hakim
# 3. Rafa Anurwansyah
# 4. Satria Aprilliansyah
# 5. Fiqih Ramadhan

# %%
# %%writefile input_data.cpp
# #include <iostream>
# #include <string>
# using namespace std;
#
# int main() {
#     string namaSiswa;
#     int umur;
#
#     cout << "Masukkan Nama (1 Kata) : ";
#     cin >> namaSiswa;
#
#     cout << "Masukkan Umur Anda     : ";
#     cin >> umur;
#
#     cout << "\nHalo " << namaSiswa << ", ternyata umur kamu " << umur << " tahun ya!" << endl;
#     return 0;
# }
# Out:
# Writing input_data.cpp

# %%
# !g++ input_data.cpp -o input_data

# !./input_data
# Out:
# Masukkan Nama (1 Kata) : habibi
# Masukkan Umur Anda     : 15
#
# Halo habibi, ternyata umur kamu 15 tahun ya!
